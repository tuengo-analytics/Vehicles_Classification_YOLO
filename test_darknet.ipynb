# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.15 MiB | 3.49 MiB/s, done.
# Resolving deltas: 100% (6735/6735), done.
# /content/darknet

# %% [markdown]
# Start from here

# %%
#!mkdir -p darknet
#%cd darknet
# Out:
# /content/darknet

# %%
# Copy the Darkent compiled version to the Colab
# !cp -v "/content/gdrive/My Drive/darknet/bin/darknet" .
# !chmod +x ./darknet
# Out:
# '/content/gdrive/My Drive/darknet/bin/darknet' -> './darknet'

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
#Use original yolov3.weights
# !cp "/content/gdrive/My Drive/darknet/classes8/yolov3.weights" ./yolov3.weights

# %%
# Check YOLO Setup
# !./darknet detect cfg/yolov3.cfg "./yolov3.weights" data/person.jpg -dont-show
imShow('predictions.jpg')
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
obj_data='obj.data'
yolo_cfg='yolov3_test.cfg'
yolo_weights='yolov3_8000_neg.weights'

# %%
# !cp "/content/gdrive/My Drive/darknet/classes8/obj.names" ./
# !cp "/content/gdrive/My Drive/darknet/train.txt" ./
# !cp "/content/gdrive/My Drive/darknet/test.txt" ./
#!cp "/content/gdrive/My Drive/darknet/classes8/"$obj_data ./
#!cp "/content/gdrive/My Drive/darknet/classes8/"$yolo_cfg ./
#!cp "/content/gdrive/My Drive/darknet/classes8/"$yolo_weights ./

# %%
rootDir="/content/gdrive/My Drive/darknet"

# %%
fildir=rootDir+'/newImg'
from os import listdir
test_images = [file for file in listdir(fildir) if file.endswith(".jpg") or file.endswith(".png") or file.endswith(".jpeg")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b60768f5105e> in <module>()
# ----> 1 fildir=rootDir+'/newImg'
#       2 from os import listdir
#       3 test_images = [file for file in listdir(fildir) if file.endswith(".jpg") or file.endswith(".png") or file.endswith(".jpeg")]
#
# NameError: name 'rootDir' is not defined

# %%
# Test one image first
# !./darknet detector test "/content/drive/My Drive/darknet/obj.data" "/content/drive/My Drive/darknet/yolov3_test.cfg" "/content/drive/My Drive/darknet/yolov3_final.weights" "/content/drive/My Drive/darknet/images.jpg" -dont_show -thresh 0.02
# !./darknet detector test "$rootDir"/classes8/$obj_data "$rootDir"/classes8/$yolo_cfg "$rootDir"/classes8/$yolo_weights "$fildir"/test/ambu57.jpg -dont_show
imShow('predictions.jpg')
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
import os
# If above cell working, then loop through all test images and test
# !mkdir -p "$rootDir"/verification
#!cat > "$rootDir"/verification/data.log
for pic in test_images:
  os.path.join(fildir,pic)
  # !./darknet detector test "$rootDir"/classes8/$obj_data "$rootDir"/classes8/$yolo_cfg "$rootDir"/classes8/$yolo_weights "$fildir/$pic" -dont_show cat >> "$rootDir"/verification/dat.log
  imShow('predictions.jpg')
  #save predictions.jpg to local
  # !mv predictions.jpg "$rootDir"/verification/$pic
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
video_name="fire_truck1"

# %%
# !./darknet detector demo "$rootDir"/classes8/$obj_data "$rootDir/classes8/$yolo_cfg" "$rootDir"/classes8/$yolo_weights "$rootDir/videos/$video_name".mp4 -dont_show -i 0 -out_filename "$rootDir/videos/$video_name".avi
# Out:
# Streaming output truncated to the last 5000 lines.
# fire_truck: 97%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 93%
#
# FPS:12.8
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 99%
#
# FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 98%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 99%
#
# FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 98%
#
# FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 93%
#
# FPS:13.5
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 98%
#
# FPS:13.6
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 96%
#
# FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 98%
#
# FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 99%
#
# FPS:14.5
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 97%
#
# FPS:13.8
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 98%
#
# FPS:13.2
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 97%
#
# FPS:13.8
#
#  cvWriteFrame
# Objects:
#
# fire_truck: 100%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# ...
