# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd /content/
# !rm -rf darknet
# !git clone https://github.com/kriyeng/darknet/
# Out:
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Jun 17 22:34 .
# drwxr-xr-x 1 root root 4096 Jun 17 18:41 ..
# drwxr-xr-x 1 root root 4096 Jun 16 16:13 .config
# drwx------ 4 root root 4096 Jun 17 19:33 gdrive
# drwxr-xr-x 1 root root 4096 Jun 10 16:28 sample_data
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.15 MiB | 16.04 MiB/s, done.
# Resolving deltas: 100% (6735/6735), done.
# total 24
# drwxr-xr-x  1 root root 4096 Jun 17 22:34 .
# drwxr-xr-x  1 root root 4096 Jun 17 18:41 ..
# drwxr-xr-x  1 root root 4096 Jun 16 16:13 .config
# drwxr-xr-x 12 root root 4096 Jun 17 22:34 darknet
# drwx------  4 root root 4096 Jun 17 19:33 gdrive
# drwxr-xr-x  1 root root 4096 Jun 10 16:28 sample_data

# %%
# !mkdir -p darknet
# %cd darknet
# Out:
# /content/darknet

# %%
# Copy the Darkent compiled version to the Colab
# !cp -v "/content/gdrive/My Drive/darknet/bin/darknet" .
# !chmod +x ./darknet
# Out:
# '/content/gdrive/My Drive/darknet/bin/darknet' -> './darknet'

# %%
import time
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline
  time.sleep(2)
  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
fildir="/content/gdrive/My Drive/darknet/img/test"
# checking the installation by inferencing existing images
from os import listdir
test_images = [file for file in listdir(fildir) if file.endswith(".jpg") or file.endswith(".png") ]

# %%
test_images
# Out:
# ['bus35.jpg',
#  'usps63.jpg',
#  'usps119.jpg',
#  'usps187.jpg',
#  'bus116.jpg',
#  'bus170.jpg']

# %%
#!cp "/content/gdrive/My Drive/darknet/obj_yf.names" ./
# !cp "/content/gdrive/My Drive/darknet/train.txt" ./
# !cp "/content/gdrive/My Drive/darknet/test.txt" ./
#!cp "/content/gdrive/My Drive/darknet/obj.data" ./
#!cp "/content/gdrive/My Drive/darknet/cfg/yolov3_test.cfg" ./cfg/yolov3.cfg
#!cp "/content/gdrive/My Drive/darknet/weights/yolov3_2000.weights" ./yolov3_2000.weights

# %%
fileDir="/content/gdrive/My\ Drive/darknet/"

# %%
# to be called only when needed
def generateTrainFile():
  # !ls "/content/gdrive/My Drive/darknet/img/train"/*.jpg  > "/content/gdrive/My Drive/darknet"/train.txt
  # !ls "/content/gdrive/My Drive/darknet/img/train"/*.png  >> "/content/gdrive/My Drive/darknet"/train.txt

# %%
generateTrainFile()
# !cat "/content/gdrive/My Drive/darknet"/train.txt

# %%
# !ls /content/gdrive/My\ Drive/darknet/img/train/*.txt | wc -l
# !ls /content/gdrive/My\ Drive/darknet/img/train/*.jpg | wc -l
# !ls /content/gdrive/My\ Drive/darknet/img/train/*.png | wc -l

# %%
# to be called only when needed
def generateTestFile():
  # !ls "/content/gdrive/My Drive/darknet/img"/test/*.jpg > "/content/gdrive/My Drive/darknet"/test.txt
  # !ls "/content/gdrive/My Drive/darknet/img"/test/*.png >> "/content/gdrive/My Drive/darknet"/test.txt

# %%
#generateTestFile()
# !cat "/content/gdrive/My Drive/darknet/test.txt"

# %%
# !cp /content/gdrive/My\ Drive/darknet/test.txt ./
#!cp /content/gdrive/My\ Drive/darknet/obj_yf.names ./

# %%
# !ls /content/gdrive/My\ Drive/darknet/img/train/train.txt

# %%
# !cp /content/gdrive/My\ Drive/darknet/cfg/obj.data ./obj.data

# %% [markdown]
# Train YOLO

# %%
# !cp -r "/content/gdrive/My Drive/darknet/classes8/obj.data" ./
# !cp -r "/content/gdrive/My Drive/darknet/classes8/obj.names" ./
#!cp -r "/content/gdrive/My Drive/darknet/test.txt" ./
# !cp -r "/content/gdrive/My Drive/darknet/train.txt" ./
# !cp -r "/content/gdrive/My Drive/darknet/classes8/yolov3.cfg" ./
#!cp -r "/content/gdrive/My Drive/darknet/darknet53.conv.74" ./

# %%
#!./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3.cfg" "/content/gdrive/My Drive/darknet/weights/yolov3_last.weights" -dont_show
#!./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/cfg/yolov3.cfg" "/content/gdrive/My Drive/darknet/weights/yolov3_last.weights" -dont_show > "/content/gdrive/My Drive/darknet/check"/train.log
# !./darknet detector train "/content/gdrive/My Drive/darknet/classes8/obj.data" "/content/gdrive/My Drive/darknet/classes8/yolov3.cfg" "/content/gdrive/My Drive/darknet/classes8/yolov3_final_1600.weights" -dont_show
# Out:
# yolov3
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# !mv ./backup/* /content/gdrive/My\ Drive/darknet/classes8/backup/trial2_300Iterations

# %%
# Model prediction for images
# !./darknet detector test ./obj.data "/content/gdrive/My Drive/darknet/cfg/yolov3_test.cfg" "/content/gdrive/My Drive/darknet/weights/yolov3_2000.weights" -dont_show
#imShow('predictions.jpg')
#./darknet detector test data/voc.data yolo-voc.cfg yolo-voc.weights -dont_show
# Out:
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# Cannot load image data/labels/53_0.png
# Cannot load image data/labels/54_0.png
# Cannot load image data/labels/55_0.png
# ...
